# %% [markdown]
# Liabrary Management system

# %%
# Main Data of books and Writters
famous_books= [
    "The Catcher",
    "The Hobbit",
    "The Lord ", 
    "The Da Vinci Code",
    "The Alchemist",
    "The Hunger Games",
    "The Fault Stars",
]
writters = [
    "Hassan",
    "Basit",
    "Ahmer",
    "Ali",
]

# All Book Detail function 

def view_books():
  print("\nAll Books :")
  for book in famous_books:
    print(book)

# Search Book function Info

def search_books():
  print("\nSearch Books :")
  search_book = input("Enter a book name : ")
  if search_book.title()  in (famous_books):
    print(f"Book Found : {search_book}")
  else:
    print("Book Not Found")

# borrow book function Info

def borrow_book():
  print("\nBorrow Books :")

  book_name = input("Enter the book name : ")

  if finding_book(book_name):
    print (f"you borrowed the book : {book_name}")
    borrowd_book.append(book_name)      # store borrowd book in list 
  else:
    print("Book Not Found")

# Borrow book Finding from list 

def finding_book (book_name):
  book_name = book_name.title()
  return book_name in famous_books

# Return book function Info

def return_book():
  print("\nReturn Books :")
  user_name = input("Enter your name : ")
  book_name = input("Enter the book name : ")

  if book_name in borrowd_book:
    print (f"you return the book : {book_name}")
    borrowd_book.remove(book_name) # return borrowed book 
  else:
    print("Book Not Found")

# All writer function Info

def writers():
  print ("\nAll Writers :")
  for writer in writters:
    print (writer)



borrowd_book = []

while True :
          print ("\nAnas Library ")
  
          print ("\nChoose an option Do you want :")
          print ("1. View all books")
          print ("2. Search for a book")
          print ("3. Borrow a book")
          print ("4. Return a book")
          print ("5. View all Writters")
          print ("6. Exit")

          choice = input("Enter number ( 1 to 6 ) : ")
          if choice == '1' :
            view_books()

          elif choice == '2' :
            search_books()

          elif choice == '3' :
            borrow_book()

          elif choice == '4' :
            return_book()

          elif choice =='5' :
           writers()

          elif choice =='6' :
            print ("Thank You For Using Library System")
            print ("Select \"y\" for use again ")
            restart=input("Do you want to use library system : ") 
            restart=restart.lower()
            if restart == "y":
              continue
            else:
              print ("Thank You For Using Library System")
              break
          else:
            print("Please enter  (1 to 6) only")
